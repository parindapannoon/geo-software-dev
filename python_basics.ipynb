# %% [markdown]
# Python 101 -- follow along

# %%
# This is a comment.
# tktkt
# kd
#sdd

# %%
'''This is also a comment
but it can go over multiple lines.'''
# Out:
# 'This is also a comment\nbut it can go over multiple lines.'

# %%
"""This 
as
well"""
# Out:
# 'This \nas\nwell'

# %%
variable = 24
variable_2 = "This is text!"
variable_3 = 45.474

# %%
type(variable_3)
# Out:
# float

# %%
y = 4.6
type(y)
print(y)
# Out:
# 4.6

# %%
y
# Out:
# 4.6

# %%
round(y)
# Out:
# 5

# %%
rounded = round(y)

# %%
# See how rounding the variable changed the type.
type(rounded)
# Out:
# int

# %%
list_1 = ["This is a list", "that contains", "both strings" "and numbers: ", 234, 34.56]
print(list_1)
type(list_1)
# Out:
# ['This is a list', 'that contains', 'both stringsand numbers: ', 234, 34.56]
# list

# %%
list_1
# Out:
# ['This is a list', 'that contains', 'both stringsand numbers: ', 234, 34.56]

# %%
tuple_1 = ("This is a tuple", "that contains", "both strings" "and numbers: ", 234, 34.56)
print(tuple_1)
type(tuple_1)
# Out:
# ('This is a tuple', 'that contains', 'both stringsand numbers: ', 234, 34.56)
# tuple

# %%
# Access the first value via index
list_1[0]
# Out:
# 'This is a list'

# %%
# Access a range of values
tuple_1[3:]
# Out:
# (234, 34.56)

# %%
# Try to change an immutiable data type
tuple_1[3] = 345
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-428bace61b50> in <module>
#       1 # Try to change an immutiable data type
# ----> 2 tuple_1[3] = 345
#
# TypeError: 'tuple' object does not support item assignment

# %%
variable_str = ""
var_int = int()
var_float = float()

# %%
type(var_int)
# Out:
# int

# %%
example_dict = {
    "name": "Jupyter",
    "age": 20
}
# Access a specific key's value
print(example_dict["name"])
print(example_dict["age"])
# Out:
# Jupyter
# 20

# %%
# This one doesn't exist...
print(example_dict["test"])

# %%
# If, elif, else -- conditional statements
x = "other thing"
if x == True:
    print("True")
elif x == "other thing":
    print("uh oh!")
elif x == True:
    print("True #2!")
else:
    print(False)
# Out:
# uh oh!

# %%
# Defining a function
def hello_function(x="", y="", z="z"):
    print("Hello " + x + y + z)

# %%
hello_function(z="test",x="test_y",y="1234")
# Out:
# Hello test_y1234test

# %%
test_list = ["this is a thing", 345, 5.356, True, None, {"key":"value"}]

# %%
# For loop
for this_is_an_item in test_list:
    print(this_is_an_item)
    print(this_is_an_item, this_is_an_item)
# Out:
# this is a thing
# this is a thing this is a thing
# 345
# 345 345
# 5.356
# 5.356 5.356
# True
# True True
# None
# None None
# {'key': 'value'}
# {'key': 'value'} {'key': 'value'}

# %%
def print_a_thing(test_3):
    print("Hello world!")
    print(test_3)
x = None
print(x)
print_a_thing("text")
print_a_thing(58)
print_a_thing(848.33)
print_a_thing("more text")
# Out:
# None
# Hello world!
# text
# Hello world!
# 58
# Hello world!
# 848.33
# Hello world!
# more text

# %%
import sys
print(sys.path)
help("modules")
# Out:
# ['C:\\Users\\b1041827\\repos\\geo-software-dev', 'C:\\Program Files\\ArcGIS\\Pro\\Resources\\ArcPy', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\python39.zip', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\DLLs', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3', '', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib\\site-packages', 'C:\\Program Files\\ArcGIS\\Pro\\bin', 'C:\\Program Files\\ArcGIS\\Pro\\Resources\\ArcToolbox\\Scripts', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib\\site-packages\\future-0.18.2-py3.9.egg', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib\\site-packages\\pytz-2022.1-py3.9.egg', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib\\site-packages\\pywin32security', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib\\si
# ...

# %%
this_is_a_list = [2, 5, 10, 100, 1]
type(this_is_a_list)
# Out:
# list

# %%
min(this_is_a_list)
# Out:
# 1

# %%
max(this_is_a_list)
# Out:
# 100

# %%
sum(this_is_a_list)
# Out:
# 118

# %%
abs(-100)
# Out:
# 100

# %%
pow(7, 3)
# Out:
# 343

# %%
len(this_is_a_list)
# Out:
# 5

# %%
len(this_is_a_list[3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-91907cf42c24> in <module>
# ----> 1 len(this_is_a_list[3])
#
# TypeError: object of type 'int' has no len()

# %%
len("testtesttest")
# Out:
# 12

# %%
sorted(this_is_a_list)
# Out:
# [1, 2, 5, 10, 100]

# %%
this_is_a_list
# Out:
# [2, 5, 10, 100, 1]

# %%
sorted(this_is_a_list, reverse=True)
# Out:
# [100, 10, 5, 2, 1]

# %%
this_is_a_dict = {"test": 1, "a": 6, "b": 7}

# %%
# Sort the dictionary -- this does the keys by default
sorted(this_is_a_dict)
# Out:
# ['a', 'b', 'test']

# %%
# Explicitly sort values
sorted(this_is_a_dict.values())
# Out:
# [1, 6, 7]

# %%
# Explicitly sort keys
sorted(this_is_a_dict.keys())
# Out:
# ['a', 'b', 'test']

# %%
this_is_a_tuple = (2, 5, 10, 100, 1)

# %%
sorted(this_is_a_tuple)
# Out:
# [1, 2, 5, 10, 100]

# %%
this_is_a_tuple
# Out:
# (2, 5, 10, 100, 1)

# %%
this_is_a_tuple[3] = 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-8d8c2feb61fe> in <module>
# ----> 1 this_is_a_tuple[3] = 2
#
# TypeError: 'tuple' object does not support item assignment

# %%
this_is_a_list[3] = 2

# %%
this_is_a_list
# Out:
# [2, 5, 10, 2, 1]

# %%
this_is_a_list.append(3)

# %%
input_text = input()
# Out:
# variable input text

# %%
print(input_text)
# Out:
# variable input text

# %%
this_is_a_list[6] = 6
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-104-dd1973f4c19c> in <module>
# ----> 1 this_is_a_list[6] = 6
#
# IndexError: list assignment index out of range

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_102',
#  '_11',
#  '_13',
#  '_14',
#  '_16',
#  '_17',
#  '_19',
#  '_2',
#  '_20',
#  '_21',
#  '_22',
#  '_23',
#  '_24',
#  '_25',
#  '_26',
#  '_27',
#  '_30',
#  '_31',
#  '_32',
#  '_4',
#  '_55',
#  '_59',
#  '_7',
#  '_74',
#  '_75',
#  '_76',
#  '_77',
#  '_78',
#  '_79',
#  '_8',
#  '_81',
#  '_82',
#  '_83',
#  '_85',
#  '_88',
#  '_89',
#  '_91',
#  '_92',
#  '_95',
#  '_97',
#  '_99',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i100',
#  '_i101',
#  '_i102',
#  '_i103',
#  '_i104',
#  '_i105',
#  '_i106',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
#  '_i35',
#  '_i36',
# ...

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '# This is a comment.',
#   "'''This is also a comment\nbut it can go over multiple lines.'''",
#   '"""This \nas\nwell""""',
#   '"""This \nas\nwell"""',
#   'variable = 24\nvariable_2 = "This is text!"\nvariable_3 = 45.474',
#   'variable = 24\nvariable_2 = "This is text!"\nvariable_3 = 45.474',
#   'type(variable)',
#   'type(variable_3)',
#   'y = 4.6\ntype(y)\nprint(y)',
#   'y = 4.6\ntype(y)\nprint(y)',
#   'y = 4.6\ntype(y)\n#print(y)',
#   'y = 4.6\ntype(y)\nprint(y)',
#   'y',
#   'round(y)',
#   'rounded = round(y)',
#   'type(rounded)',
#   'list_1 = ["This is a list", "that contains", "both strings" "and numbers: ", 234, 34.56]\nprint(list_1)\ntype(list_1)',
#   'sort(list_1)',
# ...

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'this_is_a_list = [2, 5, 10, 100, 1]',
#   'min(this_is_a_list)',
#   'max(this_is_a_list)',
#   'pow(7, 3)',
#   'sum(this_is_a_list)',
#   'abs(-100)',
#   'this_is_a_list = [2, 5, 10, 100, 1]\ntype(this_is_a_list)',
#   'pow(7, 3)',
#   'len(this_is_a_list)',
#   'sorted(this_is_a_list)',
#   'this_is_a_list',
#   'this_is_a_dict = {"test": 1, "a": 6, "b": 7}',
#   'sorted(this_is_a_dict)',
#   'sorted(this_is_a_dict.values())',
#   'dir()',
#   'globals()',
#   'locals()'],
#  '_oh': {2: 1,
#   3: 100,
#   4: 343,
#   5: 118,
#   6: 100,
#   7: list,
#   8: 343,
#   9: 5,
#   10: [1, 2, 5, 10, 100],
#   11: [2, 5, 10, 100, 1],
#   13: ['a', 'b', 'test'],
#   14: [1, 6, 7],
#   15: ['In',
# ...

# %%
import sys

# %%
sys.version
# Out:
# '3.7.3 (default, Apr 24 2019, 15:29:51) [MSC v.1915 64 bit (AMD64)]'

# %%
sys.modules
# Out:
# {'sys': <module 'sys' (built-in)>,
#  'builtins': <module 'builtins' (built-in)>,
#  '_frozen_importlib': <module 'importlib._bootstrap' (frozen)>,
#  '_imp': <module '_imp' (built-in)>,
#  '_thread': <module '_thread' (built-in)>,
#  '_warnings': <module '_warnings' (built-in)>,
#  '_weakref': <module '_weakref' (built-in)>,
#  'zipimport': <module 'zipimport' (built-in)>,
#  '_frozen_importlib_external': <module 'importlib._bootstrap_external' (frozen)>,
#  '_io': <module 'io' (built-in)>,
#  'marshal': <module 'marshal' (built-in)>,
#  'nt': <module 'nt' (built-in)>,
#  'winreg': <module 'winreg' (built-in)>,
#  'encodings': <module 'encodings' from 'C:\\ProgramData\\Anaconda3\\lib\\encodings\\__init__.py'>,
#  'codecs': <module 'codecs' from 'C:\\ProgramData\\Anaconda3\\lib\\codecs.py'>,
#  '_codecs': <module '_codecs' (built-in)>,
#  'encodings.aliases': <module 'encodings.aliases' from 'C:\\ProgramData\\Anaconda3\\lib\\encodings\\aliases.py'>,
# ...

# %%
sys.path
# Out:
# ['C:\\Users\\b1041827\\repos\\PLUS_softwaredev_2022',
#  'C:\\ProgramData\\Anaconda3\\python37.zip',
#  'C:\\ProgramData\\Anaconda3\\DLLs',
#  'C:\\ProgramData\\Anaconda3\\lib',
#  'C:\\ProgramData\\Anaconda3',
#  '',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\b1041827\\.ipython']

# %%
import os
here_i_am = os.getcwd()

# %%
pretend_file = os.path.join(here_i_am, "test.py")
print(pretend_file)
# Out:
# C:\Users\b1041827\repos\PLUS_softwaredev_2022\test.py

# %%
os.path.isdir(here_i_am)
# Out:
# True

# %%
os.path.dirname(here_i_am)
# Out:
# 'C:\\Users\\b1041827\\repos'

# %%
os.path.basename(here_i_am)
# Out:
# 'PLUS_softwaredev_2022'

# %%
os.path.basename(pretend_file)
# Out:
# 'test.py'

# %%
import shutil

# %%
shutil.which('python')
# Out:
# 'C:\\ProgramData\\Anaconda3\\python.EXE'

# %%
shutil.which('conda')
# Out:
# 'C:\\ProgramData\\Anaconda3\\Library\\bin\\conda.BAT'

# %%
import math
math.pi
# Out:
# 3.141592653589793

# %%
import datetime
datetime.datetime.now()
# Out:
# datetime.datetime(2022, 5, 2, 11, 29, 37, 94284)

# %%
print(datetime.datetime.now())
# Out:
# 2022-05-02 11:29:47.778093

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2022, 5, 2, 11, 30, 9, 518524)

# %%
import logging

def test_logging(x):
    # The log messages aren't usually delivered
    # in a notebook, but they would be passed
    # in the background to a logfile or database
    # depending on how you configure the settings.
    message = None
    if type(x) is int:
        message = "{} is an integer.".format(x)
        logging.info("{} is an integer.".format(x))
    elif type(x) is str:
        message = "{} is a string.".format(x)
        logging.info("{} is a string.".format(x))
    else:
        message = "What is this?: {}".format(x)
        logging.debug("What is this?: {}".format(x))
    # This is just so that you can see the text,
    # but the package would also give it a level like
    # info, debug, warning, error, critical, or custom
    # levels to help you figure out what is important.
    print(message)

# %%
test_logging("48.7")
# Out:
# 48.7 is a string.

# %%
test_logging(48.7)
# Out:
# What is this?: 48.7

# %%
test_logging(48)
# Out:
# 48 is an integer.

# %%
import colorsys
## checkout https://ethanschoonover.com/solarized/
## yellow = 181 137 0 in RGB
# Scale between 0 and 1
red = 181/255
green = 137/255
blue = 0/255
colorsys.rgb_to_hsv(red, green, blue)
# Out:
# (0.12615101289134437, 1.0, 0.7098039215686275)

# %%
import untitled
# Out:
# ['C:\\ProgramData\\Anaconda3\\lib\\site-packages\\spyder\\plugins\\help\\utils', 'C:\\Users\\b1041827\\repos\\PLUS_softwaredev_2022', 'C:\\Users\\b1041827\\repos\\PLUS_softwaredev_2022\\past_lessons', 'C:\\ProgramData\\Anaconda3\\python38.zip', 'C:\\ProgramData\\Anaconda3\\DLLs', 'C:\\ProgramData\\Anaconda3\\lib', 'C:\\ProgramData\\Anaconda3', '', 'C:\\Users\\b1041827\\AppData\\Roaming\\Python\\Python38\\site-packages', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32\\lib', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\Pythonwin', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\b1041827\\.ipython', 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\astroid\\brain']
#
# Please wait a moment while I gather a list of all available modules...
#
# Cython              brain_six           math                socks
# ...

# %%
say_hello("test")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-2bbd6995d0e1> in <module>
# ----> 1 say_hello("test")
#
# NameError: name 'say_hello' is not defined

# %%
untitled.say_hello("test")
# Out:
# Hello, world! Hello test
# 'test'

# %%
value_untitled = untitled.say_hello("lovely people")
# Out:
# Hello, world! Hello lovely people

# %%
print(value_untitled)
# Out:
# lovely people
